# %%
# 라이브러리
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from mplsoccer import Pitch

# %%
nuri_pitch=plt.imread('img/nuri-futsal.png')

# %%
player_df=pd.read_csv('../df/heatmap/testMatch-heatmap-df.csv',index_col=0)

# %%
player_df
# Out:
#      player_id  team      team_color       coord  coord_x  coord_y
# 0          OJY     1   [230, 61, 37]  [368, 212]      368      212
# 1          SMJ     1   [230, 61, 37]  [191, 354]      191      354
# 2          KSW     1   [230, 61, 37]   [62, 204]       62      204
# 3          SDG     1   [230, 61, 37]   [232, 31]      232       31
# 4          SHW     0  [38, 110, 219]  [457, 204]      457      204
# ...        ...   ...             ...         ...      ...      ...
# 9627       SMJ     1   [230, 61, 37]  [590, 226]      590      226
# 9628       KYS     0  [38, 110, 219]  [746, 233]      746      233
# 9629       OJY     1   [230, 61, 37]   [452, 40]      452       40
# 9630       SDG     1   [230, 61, 37]  [533, 163]      533      163
# 9631       KSI     0  [38, 110, 219]   [639, 95]      639       95
#
# [9632 rows x 6 columns]

# %%
team_split = {'Team-A':player_df[player_df['team'] == 0],
                      'Team-B':player_df[player_df['team'] == 1]}

# %%
['left-pa' if 60<80]
# Out:
#   Cell In[37], line 1
#     ['left-pa' if 60<80]
#      ^
# SyntaxError: expected 'else' after 'if' expression

# %%
# 그래프 그리기
fig, ax = plt.subplots()
sns.kdeplot(x=team_split['Team-A'].query("player_id!='KYS'")['coord_x'],
            y=team_split['Team-A'].query("player_id!='KYS'")['coord_y'],
            fill=True,
            thresh=0,
            levels=10,
            cmap="Blues",
            alpha=0.8,
            ax=ax)  # your_data는 분포를 시각화할 데이터입니다.

# 이미지 배경에 그래프 추가
ax.imshow(nuri_pitch, extent=[2.5, 802.5, 2.5, 402.5])
plt.gca().invert_yaxis()
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
img=plt.imread('../viz/heatmap-team/testMatch-heatmap-team-a.png')

# %%
img.shape
# Out:
# (268, 515, 4)

# %%
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
plt.imshow(nuri_pitch)
plt.axis('off')
plt.show()
